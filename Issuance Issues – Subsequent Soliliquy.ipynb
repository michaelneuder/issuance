# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
TOTAL_SUPPLY = 120_000_000
MIN_STAKED = 1

STAKED = np.linspace(MIN_STAKED, TOTAL_SUPPLY, 1000)

# %%
y = 2.6 * 64 / np.sqrt(STAKED)

# %%
2.6 * 64 / np.sqrt(10_000_000), 2.6 * 64 / np.sqrt(30_000_000), 2.6 * 64 / np.sqrt(50_000_000)
# Out:
# (0.052620300265201835, 0.030380344522953212, 0.023532513677888302)

# %%
f, ax = plt.subplots(figsize=(9,6))
ax.plot(STAKED, y, color='darkred', linewidth=3, alpha=1)

ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("inverse-root nominal yield", size=16)

plt.show()

# %%
inflation = STAKED * y

# %%
2.6 * 64 * np.sqrt(10_000_000), 2.6 * 64 * np.sqrt(30_000_000), 2.6 * 64 * np.sqrt(50_000_000)
# Out:
# (526203.0026520183, 911410.3356885965, 1176625.6838944152)

# %%
f, ax = plt.subplots(figsize=(9,6))
ax.plot(STAKED, inflation, color='green', linewidth=3, alpha=1)

ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)
ax.grid(alpha=0.4)
ax.set_ylabel("inflation (ETH)", size=14)


ax.set_title("inverse-root inflation", size=16)

plt.show()

# %%
f, axarr = plt.subplots(ncols=2, figsize=(11,5))

ax = axarr[0]
ax.plot(STAKED, inflation, color='darkgreen', linewidth=3, alpha=1)

ax.set_ylim(0,2_000_000)
yticks = np.arange(0, 2_000_001, 500_000)
ax.set_yticks(yticks)
ax.set_ylabel("inflation (ETH)", size=14)

ax = axarr[1]
ax.plot(STAKED, inflation/TOTAL_SUPPLY, color='darkgreen', linewidth=3, alpha=1)
ax.set_yticks([0, 0.002,0.004,0.006,0.008,0.01, 0.012, 0.014])
ax.set_yticklabels(["0%", "0.2%", "0.4%", "0.6%", "0.8%", "1%", "1.2%", "1.4%"])
ax.set_ylabel("inflation (%)", size=14)

for ax in axarr:    
    ax.set_xlim(0,120_000_000)
    xticks = np.arange(0, 120_000_001, 20_000_000)
    ax.set_xticks(xticks)
    ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
    ax.set_xlabel("stake (ETH)", size=14)
    ax.grid(alpha=0.4)


plt.show()

# %%
def realYieldCalc(amt):
    y = 2.6 * 64 / np.sqrt(amt)
    i = y * amt
    return y - (i/120_000_000)

# %%
realYieldCalc(10_000_000), realYieldCalc(30_000_000), realYieldCalc(50_000_000)
# Out:
# (0.04823527524310168, 0.02278525839221491, 0.013727299645434843)

# %%
f, ax = plt.subplots(figsize=(9,6))
ax.plot(STAKED, y, color='darkred', linewidth=3, alpha=1, label='nominal yield')
ax.plot(STAKED, y-inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, alpha=1, label='real yield')

ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("inverse-root nominal & real yield", size=16)
ax.legend()

plt.show()

# %%
demand = 0.000002*np.sqrt(STAKED)

# %%
0.000002*np.sqrt(10_000_000), 0.000002*np.sqrt(30_000_000), 0.000002*np.sqrt(50_000_000)
# Out:
# (0.006324555320336759, 0.010954451150103323, 0.014142135623730949)

# %%
f, ax = plt.subplots(figsize=(9,6))
ax.plot(STAKED, demand, color='magenta', linewidth=3, alpha=1)

ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)


ax.set_yticks([0, 0.005, 0.01, 0.015, 0.02])
ax.set_yticklabels(["0%", "0.5%", "1%", "1.5%", "2%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("hypothetical supply", size=16)

plt.show()

# %%
def nominalYieldCalc(amt):
    return 2.6 * 64 / np.sqrt(amt)

def demandCalc(amt):
    return 0.000002*np.sqrt(amt)

def realYieldCalc(amt):
    y = 2.6 * 64 / np.sqrt(amt)
    i = y * amt
    return y - (i/120_000_000)

# %%
nominalYieldCalc(83_200_000), demandCalc(83_200_000), realYieldCalc(83_200_000)
# Out:
# (0.018242806801586207, 0.018242806801586207, 0.005594460752486437)

# %%
f, ax = plt.subplots(figsize=(9,6))
ax.plot(STAKED, demand, color='magenta', linewidth=3, alpha=1, label='hypothetical supply')
ax.plot(STAKED, y, color='darkred', linewidth=3, alpha=1, label='nominal yield')



ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.scatter(83_200_000, nominalYieldCalc(83_200_000), marker='x', s=200, color='gold', linewidth=4, 
           label='equilibrium', zorder=3)

ax.grid(alpha=0.4)
ax.set_title("inverse-root nominal yield & hypothetical supply", size=16)
ax.legend()

plt.show()

# %%
f, ax = plt.subplots(figsize=(9,6))


ax.scatter(83_200_000, nominalYieldCalc(83_200_000), marker='x', s=200, color='gold', linewidth=4, 
           label='equilibrium nominal yield', zorder=3)
ax.scatter(83_200_000, realYieldCalc(83_200_000), marker='o', s=100, color='orangered', linewidth=4, 
           label='equilibrium real yield', zorder=3, facecolors="none")

ax.plot(STAKED, demand, color='magenta', linewidth=3, alpha=1, label='hypothetical supply', zorder=2)
ax.plot(STAKED, y, color='darkred', linewidth=3, alpha=1, label='nominal yield', zorder=2)
ax.plot(STAKED, y-inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, alpha=1, label='real yield', zorder=2)

ax.arrow(83_200_000, nominalYieldCalc(83_200_000), 0, -0.006,
         length_includes_head=False, head_width=1_000_000, head_length=0.003, color='black')

ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("equilibrium-implied real yield", size=16)
ax.legend()

plt.show()

# %%
h_y = 2.6 * 64 / (np.sqrt(STAKED)*(1+2**(-25)*STAKED))

# %%
def calcAlt(amt):
    return 2.6 * 64 / (np.sqrt(amt)*(1+2**(-25)*amt))

# %%
calcAlt(10_000_000), calcAlt(30_000_000), calcAlt(50_000_000)
# Out:
# (0.040538797224316844, 0.01603971859007419, 0.009450367994767447)

# %%
f, ax = plt.subplots(figsize=(9,6))
ax.plot(STAKED, y, color='darkred', linewidth=3, alpha=1, label='current (inverse-root)')
ax.plot(STAKED, h_y, color='darkred', linewidth=3, alpha=1, linestyle='--', label='alternative (scaled-inverse-root)')

ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("scaled-inverse-root nominal yield", size=16)
ax.legend()

plt.show()

# %%
h_inflation = STAKED * h_y

# %%
def calcAltInf(amt):
    return amt * 2.6 * 64 / (np.sqrt(amt)*(1+2**(-25)*amt))

# %%
calcAltInf(10_000_000), calcAltInf(30_000_000), calcAltInf(50_000_000)
# Out:
# (405387.97224316845, 481191.5577022257, 472518.39973837236)

# %%
f, ax = plt.subplots(figsize=(9,6))
ax.plot(STAKED, inflation, color='green', linewidth=3, alpha=1, label='current (inverse-root)')
ax.plot(STAKED, h_inflation, color='green', linewidth=3, alpha=1, 
        linestyle='--', label='alternative (scaled-inverse-root)')

ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)
ax.grid(alpha=0.4)
ax.set_ylabel("inflation (ETH)", size=14)


ax.set_title("scaled-inverse-root inflation", size=16)
ax.legend()

plt.show()

# %%
def altRealYieldCalc(amt):
    y = 2.6 * 64 / (np.sqrt(amt)*(1+2**(-25)*amt))
    i = y * amt
    return y - (i/120_000_000)

# %%
altRealYieldCalc(10_000_000), altRealYieldCalc(30_000_000), altRealYieldCalc(50_000_000)
# Out:
# (0.03716056412229044, 0.01202978894255564, 0.005512714663614343)

# %%
f, ax = plt.subplots(figsize=(9,6))
ax.plot(STAKED, y, color='darkred', linewidth=3, alpha=1, label='current nominal')
ax.plot(STAKED, y-inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, alpha=1, label='current real')

ax.plot(STAKED, h_y, color='darkred', linewidth=3, alpha=1, linestyle='--', label='alternative nominal')
ax.plot(STAKED, h_y-h_inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, 
        alpha=1, linestyle='--', label='alternative  real')

ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("nominal & real yields", size=16)
ax.legend()

plt.show()

# %%
def altNominalYieldCalc(amt):
    return 2.6 * 64 / (np.sqrt(amt)*(1+2**(-25)*amt))

# %%
f, ax = plt.subplots(figsize=(9,6))
ax.plot(STAKED, demand, color='magenta', linewidth=3, alpha=1, label='hypothetical supply')
ax.plot(STAKED, y, color='darkred', linewidth=3, alpha=1, label='current nominal', zorder=2)
ax.plot(STAKED, h_y, color='darkred', linestyle='--', linewidth=3, alpha=1, label='alternative nominal')



ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.scatter(83_200_000, nominalYieldCalc(83_200_000), marker='x', s=200, color='gold', linewidth=4, 
           label='current equilibrium', zorder=3)
ax.scatter(38_660_000, altNominalYieldCalc(38_660_000), marker='x', s=200, color='grey', linewidth=4, 
           label='alternative equilibrium', zorder=3)

ax.grid(alpha=0.4)
ax.set_title("nominal yields & hypothetical supply", size=16)
ax.legend()

plt.show()

# %%
def altNominalYieldCalc(amt):
    return 2.6 * 64 / (np.sqrt(amt)*(1+2**(-25)*amt))

def demandCalc(amt):
    return 0.000002*np.sqrt(amt)

def altRealYieldCalc(amt):
    y = 2.6 * 64 / (np.sqrt(amt)*(1+2**(-25)*amt))
    i = y * amt
    return y - (i/120_000_000)

# %%
altNominalYieldCalc(38_660_000), demandCalc(38_660_000), altRealYieldCalc(38_660_000)
# Out:
# (0.012435071565567482, 0.01243543324536785, 0.008428906009527158)

# %%
f, ax = plt.subplots(figsize=(9,6))


ax.scatter(83_200_000, nominalYieldCalc(83_200_000), marker='x', s=200, color='gold', linewidth=4, 
           label='current equilibrium nominal', zorder=3)
ax.scatter(83_200_000, realYieldCalc(83_200_000), marker='o', s=100, color='orangered', linewidth=4, 
           label='current equilibrium real', zorder=3, facecolors="none")
ax.scatter(38_660_000, altNominalYieldCalc(38_660_000), marker='x', s=200, color='grey', linewidth=4, 
           label='alternative equilibrium nominal', zorder=3)
ax.scatter(38_660_000, altRealYieldCalc(38_660_000), marker='o', s=100, color='springgreen', linewidth=4, 
           label='alternative equilibrium real', zorder=3, facecolors="none")

ax.plot(STAKED, demand, color='magenta', linewidth=3, alpha=1, label='hypothetical supply', zorder=2)
ax.plot(STAKED, y, color='darkred', linewidth=3, alpha=1, label='current nominal', zorder=2)
ax.plot(STAKED, y-inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, alpha=1, label='current real', zorder=2)

ax.plot(STAKED, h_y, color='darkred', linestyle='--', linewidth=3, alpha=1, label='alternative nominal')
ax.plot(STAKED, h_y-h_inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, 
        alpha=1, linestyle='--', label='alternative real')

ax.arrow(83_200_000, nominalYieldCalc(83_200_000), 0, -0.006,
         length_includes_head=False, head_width=1_000_000, head_length=0.003, color='black')

ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("equilibria-implied real yields", size=16)
ax.legend()

plt.show()

# %%
f, ax = plt.subplots(figsize=(9,6))


ax.scatter(83_200_000, nominalYieldCalc(83_200_000), marker='x', s=200, color='gold', linewidth=4, 
           label='current equilibrium nominal', zorder=3)
ax.scatter(83_200_000, realYieldCalc(83_200_000), marker='o', s=100, color='orangered', linewidth=4, 
           label='current equilibrium real', zorder=3, facecolors="none")
ax.scatter(38_660_000, altNominalYieldCalc(38_660_000), marker='x', s=200, color='grey', linewidth=4, 
           label='alternative equilibrium nominal', zorder=3)
ax.scatter(38_660_000, altRealYieldCalc(38_660_000), marker='o', s=100, color='springgreen', linewidth=4, 
           label='alternative equilibrium real', zorder=3, facecolors="none")

ax.plot(STAKED, demand, color='magenta', linewidth=3, alpha=1, label='hypothetical supply', zorder=2)
ax.plot(STAKED, y, color='darkred', linewidth=3, alpha=1, label='current nominal', zorder=2)
ax.plot(STAKED, y-inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, alpha=1, label='current real', zorder=2)

ax.plot(STAKED, h_y, color='darkred', linestyle='--', linewidth=3, alpha=1, label='alternative nominal')
ax.plot(STAKED, h_y-h_inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, 
        alpha=1, linestyle='--', label='alternative real')

ax.arrow(83_200_000, nominalYieldCalc(83_200_000), 0, -0.011,
         length_includes_head=False, head_width=2_000_000, head_length=0.001, color='black')
ax.arrow(38_660_000, altNominalYieldCalc(38_660_000), 0, -0.0024,
         length_includes_head=False, head_width=2_000_000, head_length=0.001, color='black')


ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.022)
ax.set_yticks([0, 0.005, 0.01, 0.015, 0.02])
ax.set_yticklabels(["0%", "0.5%", "1%", "1.5%", "2%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("equilibria-implied real yields (zoomed in)", size=16)
ax.legend(bbox_to_anchor=(1., 1.01))

plt.show()

# %%
f, ax = plt.subplots(figsize=(9,5))
ax.plot(STAKED, y, color='salmon', linewidth=3, alpha=0.7, label='current')
ax.plot(STAKED, h_y, color='salmon', linewidth=3, alpha=0.7, linestyle='dashed', label='hypothetical')

ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("current vs hypothetical nominal yield", size=16)
ax.legend()

plt.show()

# %%
h_inflation = STAKED * h_y

# %%
f, axarr = plt.subplots(ncols=2, figsize=(11,5))

ax = axarr[0]
ax.plot(STAKED, inflation, color='darkgreen', linewidth=3, alpha=0.7, label='current')
ax.plot(STAKED, h_inflation, color='darkgreen', linewidth=3, alpha=0.7, label='hypothetical', linestyle='dashed')

ax.set_ylim(0,2_000_000)
yticks = np.arange(0, 2_000_001, 500_000)
ax.set_yticks(yticks)
ax.set_ylabel("inflation (ETH)", size=14)

ax = axarr[1]
ax.plot(STAKED, inflation/TOTAL_SUPPLY, color='darkgreen', linewidth=3, alpha=0.7, label='current')
ax.plot(STAKED, h_inflation/TOTAL_SUPPLY, color='darkgreen', linewidth=3, alpha=0.7, label='hypothetical', linestyle='dashed')
ax.set_yticks([0, 0.002,0.004,0.006,0.008,0.01, 0.012, 0.014])
ax.set_yticklabels(["0%", "0.2%", "0.4%", "0.6%", "0.8%", "1%", "1.2%", "1.4%"])
ax.set_ylabel("inflation (%)", size=14)

for ax in axarr:    
    ax.set_xlim(0,120_000_000)
    xticks = np.arange(0, 120_000_001, 20_000_000)
    ax.set_xticks(xticks)
    ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
    ax.set_xlabel("stake (ETH)", size=14)
    ax.grid(alpha=0.4)
    ax.legend()

plt.show()

# %%
f, ax = plt.subplots(figsize=(9,5))
ax.plot(STAKED, y, color='salmon', linewidth=3, alpha=0.7, label='current nominal yield')
ax.plot(STAKED, y-inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, alpha=0.7, label='current real yield')

ax.plot(STAKED, h_y, color='salmon', linewidth=3, alpha=0.7, label='hypothetical nominal yield', linestyle='dashed')
ax.plot(STAKED, h_y-h_inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, alpha=0.7, label='hypothetical real yield', linestyle='dashed')


ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("current real & nominal yield", size=16)
ax.legend()

plt.show()

# %%
supply = 0.00000000000000001*(STAKED**2)

# %%
f, ax = plt.subplots(figsize=(9,5))
ax.plot(STAKED, y, color='salmon', linewidth=3, alpha=0.7, label='current nominal yield')
ax.plot(STAKED, h_y, color='salmon', linewidth=3, alpha=0.7, label='hypothetical nominal yield', linestyle='dashed')

ax.plot(STAKED, supply, color='darkolivegreen', linewidth=3, alpha=0.7, label='example supply curve')


ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("current real & nominal yield", size=16)
ax.legend(loc=1)

plt.show()

# %%
f, ax = plt.subplots(figsize=(9,5))
ax.plot(STAKED, y, color='salmon', linewidth=3, alpha=0.7, label='current nominal yield')
ax.plot(STAKED, h_y, color='salmon', linewidth=3, alpha=0.7, label='hypothetical nominal yield', linestyle='dashed')

ax.plot(STAKED, supply, color='darkolivegreen', linewidth=3, alpha=0.7, label='example supply curve')


ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("current real & nominal yield", size=16)
ax.legend(loc=1)

plt.show()

# %%
# 75/25
y7525 = 2.6 * 64 / np.sqrt(30_000_000)
i7525 = y7525 * 30_000_000
y7525, i7525
# Out:
# (0.030380344522953212, 911410.3356885964)

# %%
i7525/90_000_000 # implies about ~1% annual tax
# Out:
# 0.01012678150765107

# %%
# 75/25
y2575 = 2.6 * 64 / np.sqrt(90_000_000)
i2575 = y7525 * 90_000_000
y2575, i2575
# Out:
# (0.017540100088400613, 2734231.0070657893)

# %%
i2575 / 30_000_000 # implies about a ~9% annual tax (~3x more inflation, ~1/3 amount of unstaked ETH to pay it)
# Out:
# 0.09114103356885965

# %%
## LEAVE IT HERE probably

# %%
def taxCalc(amt):
    y = 2.6 * 64 / np.sqrt(amt)
    i = y * amt
    return i / (120_000_000 - amt)

def nominalYieldCalc(amt):
    return 2.6 * 64 / np.sqrt(amt)

def realYieldCalc(amt):
    y = 2.6 * 64 / np.sqrt(amt)
    i = y * amt
    return y - (i/120_000_000)

# %%
v = -60000000*(-3 + np.sqrt(5))
nominalYieldCalc(v), taxCalc(v), realYieldCalc(v)
# Out:
# (0.024578215014035006, 0.015190172261476608, 0.015190172261476608)

# %%
f, ax = plt.subplots(figsize=(9,5))
ax.plot(STAKED, y, color='salmon', linewidth=3, alpha=0.7, label='nominal yield')
ax.plot(STAKED, taxCalc(STAKED), color='darkviolet', linewidth=3, alpha=0.7, label='tax')
ax.plot(STAKED, y-inflation/TOTAL_SUPPLY, color='cornflowerblue', linewidth=3, alpha=0.7, label='real yield')


ax.set_xlim(0,120_000_000)
xticks = np.arange(0, 120_000_001, 20_000_000)
ax.set_xticks(xticks)
ax.set_xticklabels(["{:d}m".format(int(tick/1_000_000)) for tick in xticks])
ax.set_xlabel("stake (ETH)", size=14)

ax.set_ylim(0,0.15)
ax.set_yticks([0, 0.02,0.04,0.06,0.08,0.1, 0.12, 0.14])
ax.set_yticklabels(["0%", "2%", "4%", "6%", "8%", "10%", "12%", "14%"])
ax.set_ylabel("yield (%)", size=14)

ax.grid(alpha=0.4)
ax.set_title("current nominal yield", size=16)
ax.legend()

plt.show()
